# %% [markdown]
# # E-Shikhon Web Scrapping Module

# %%
pip install selenium
# Out:
# Collecting selenium
#   Obtaining dependency information for selenium from https://files.pythonhosted.org/packages/10/56/8288d1813a68c1e0638515dbb777fce6d87d0d240e683216f956145310e6/selenium-4.11.2-py3-none-any.whl.metadata
#   Using cached selenium-4.11.2-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\shakhawat chowdhury\anaconda3\lib\site-packages (from selenium) (1.26.16)
# Collecting trio~=0.17 (from selenium)
#   Obtaining dependency information for trio~=0.17 from https://files.pythonhosted.org/packages/a3/dd/b61fa61b186d3267ef3903048fbee29132963ae762fb70b08d4a3cd6f7aa/trio-0.22.2-py3-none-any.whl.metadata
#   Using cached trio-0.22.2-py3-none-any.whl.metadata (4.7 kB)
# Collecting trio-websocket~=0.9 (from selenium)
#   Obtaining dependency information for trio-websocket~=0.9 from https://files.pythonhosted.org/packages/a5/a6/06e2373f95c12e9e8f6b910a76c86e375348ead77ab476230640666310fb/trio_websocket-0.10.3-py3-none-any.whl.metadata
#   Using cached trio_websocket-0.10.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\shakhawat chowdhury\anaconda3\lib\site-packages (from selenium) (2023.7.22)
# Requirement already satisfied: attrs>=20.1.0 in c:\users\shakhawat chowdhury\anaconda3\lib\site-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: sortedcontainers in c:\users\shakhawat chowdhury\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\shakhawat chowdhury\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Collecting outcome (from trio~=0.17->selenium)
#   Using cached outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: sniffio in c:\users\shakhawat chowdhury\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\shakhawat chowdhury\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Collecting exceptiongroup (from trio-websocket~=0.9->selenium)
#   Obtaining dependency information for exceptiongroup from https://files.pythonhosted.org/packages/fe/17/f43b7c9ccf399d72038042ee72785c305f6c6fdc6231942f8ab99d995742/exceptiongroup-1.1.2-py3-none-any.whl.metadata
#   Using cached exceptiongroup-1.1.2-py3-none-any.whl.metadata (6.1 kB)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Using cached wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\shakhawat chowdhury\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\shakhawat chowdhury\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium)
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Using cached selenium-4.11.2-py3-none-any.whl (7.2 MB)
# Using cached trio-0.22.2-py3-none-any.whl (400 kB)
# Using cached trio_websocket-0.10.3-py3-none-any.whl (17 kB)
# Using cached exceptiongroup-1.1.2-py3-none-any.whl (14 kB)
# Installing collected packages: outcome, h11, exceptiongroup, wsproto, trio, trio-websocket, selenium
# Successfully installed exceptiongroup-1.1.2 h11-0.14.0 outcome-1.2.0 selenium-4.11.2 trio-0.22.2 trio-websocket-0.10.3 wsproto-1.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver

# %%
pip install webdriver_manager
# Out:
# Requirement already satisfied: webdriver_manager in c:\users\shakhawat chowdhury\anaconda3\lib\site-packages (4.0.0)
# Requirement already satisfied: requests in c:\users\shakhawat chowdhury\anaconda3\lib\site-packages (from webdriver_manager) (2.31.0)
# Requirement already satisfied: python-dotenv in c:\users\shakhawat chowdhury\anaconda3\lib\site-packages (from webdriver_manager) (1.0.0)
# Requirement already satisfied: packaging in c:\users\shakhawat chowdhury\anaconda3\lib\site-packages (from webdriver_manager) (23.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shakhawat chowdhury\anaconda3\lib\site-packages (from requests->webdriver_manager) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shakhawat chowdhury\anaconda3\lib\site-packages (from requests->webdriver_manager) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shakhawat chowdhury\anaconda3\lib\site-packages (from requests->webdriver_manager) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shakhawat chowdhury\anaconda3\lib\site-packages (from requests->webdriver_manager) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Access the target website

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
service = Service(executable_path='C:/Users/Shakhawat Chowdhury/chromedriver-win64/chromedriver.exe')
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=service, options=options)
driver.get('https://www.daraz.com.bd/')
#driver.get('https://www.sciencedirect.com/')
import time
time.sleep(20)

# %% [markdown]
# # Access the product details

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import urllib.request
import time
from selenium.webdriver.chrome.service import Service

service = Service(executable_path='C:/Users/Shakhawat Chowdhury/chromedriver-win64/chromedriver.exe')
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=service, options=options)

driver.get('https://www.daraz.com.bd/smartphones/xiaomi-brand/')
driver.maximize_window()

# title = driver.find_element(By.XPATH,'//*[@id="root"]/div/div[2]/div/div/div[1]/div[2]/div[1]/div/div/div[2]/div[2]/a').text
# tit = driver.find_element(By.TAG_NAME,'title').get_attribute('textContent')
# heading = driver.find_element(By.ID,'head').text
# paragraph = driver.find_element(By.TAG_NAME,'p').text
# link = driver.find_element(By.XPATH,'/html/body/a').get_attribute('href')
# image = driver.find_element(By.XPATH,'/html/body/img').get_attribute('src')

title = driver.find_element(By.XPATH,'//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[3]/div[1]/div/div/div[2]/div[2]/a').text
link = driver.find_element(By.XPATH,'//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[3]/div[1]/div/div/div[2]/div[2]/a').get_attribute('href')
img = driver.find_element(By.XPATH,'//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[3]/div[1]/div/div/div[1]/div/a/img').get_attribute('src')
urllib.request.urlretrieve(img, "demo1.png")
driver.get(img)

print(title)
print(link)
print(img)

time.sleep(20)
# Out:
# Redmi 12C(6/128GB)
# https://www.daraz.com.bd/products/redmi-12c6128gb-i317913282-s1447773739.html?search=1
# https://static-01.daraz.com.bd/p/57c807417dd32c730b9e9f544fb91818.jpg

# %% [markdown]
# # Check for Other Website/Product: Apple iPhone

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import urllib.request
import time
from selenium.webdriver.chrome.service import Service

service = Service(executable_path='C:/Users/Shakhawat Chowdhury/chromedriver-win64/chromedriver.exe')
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=service, options=options)

#driver.get('https://www.daraz.com.bd/smartphones/xiaomi-brand/')
driver.get('https://www.daraz.com.bd/smartphones/apple/')

driver.maximize_window()

##Using html tag, id
# tit = driver.find_element(By.TAG_NAME,'title').get_attribute('textContent')
# heading = driver.find_element(By.ID,'head').text
# paragraph = driver.find_element(By.TAG_NAME,'p').text
# link = driver.find_element(By.XPATH,'/html/body/a').get_attribute('href')
# image = driver.find_element(By.XPATH,'/html/body/img').get_attribute('src')

title = driver.find_element(By.XPATH,'//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[3]/div[1]/div/div/div[2]/div[2]/a').text
link = driver.find_element(By.XPATH,'//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[3]/div[1]/div/div/div[1]/div/a').get_attribute('href')
img = driver.find_element(By.XPATH,'//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[3]/div[1]/div/div/div[1]/div/a/img').get_attribute('src')
urllib.request.urlretrieve(img, "demo1.png")
driver.get(img)

print(title)
print(link)
print(img)
time.sleep(20)
# Out:
# IPhone 13 128 GB Mobile Phone Smartphone
# https://www.daraz.com.bd/products/iphone-13-128-gb-mobile-phone-smartphone-i281281104-s1268970629.html?search=1
# https://static-01.daraz.com.bd/p/106ed238c0802a05e52cab15d662c377.jpg

# %% [markdown]
# # Cric_Buzz Scrapping

# %%
import sys
import time
from bs4 import BeautifulSoup
import requests

# %%
try:
        
    page=requests.get('https://www.cricbuzz.com/')                         
    
except Exception as e:                                   
    error_type, error_obj, error_info = sys.exc_info()      
    print ('ERROR FOR LINK:',url)                          
    print (error_type, 'Line:', error_info.tb_lineno)     
                                                 
time.sleep(2)   
soup=BeautifulSoup(page.text,'html.parser')
links=soup.find_all('div',attrs={'class':'cb-nws-intr'})

# %%
for i in links:
    print(i.text)
    print("\n")
# Out:
# The all-rounder has been named in England's ODI squad against New Zealand in lead-up to the World Cup in India
#
#
# Here's all you need to know about the teams in CPL 2023: their recent history, signings and probable XIs
#
#
# The 38-year-old left-armer, who made his debut in 2008, last represented Pakistan in December 2020
#
#
# South Africa will audition a bunch of youngsters in the T20Is against Australia to test their readiness for a step-up
#
#
# The move will see the tickets for India games being made available in a phased manner
#
#
# Twice in five games of the T20I series, the lower order was tasked with having to make an impact with the bat
#
#
# The modern-day dilemma between balancing the League and international commitments will be a headache for the Board.
#
#
# Missing out on Asia Cup selection would indicate so, but former captain Khaled Mahmud thinks there is still a way back for the 37-year-old
#
#
# The 74-player list includes veteran players like Javeria Khan, Anam Amin and Kainat Imtiaz
#
#
# Having qualified for the tournament, Nepal have been placed alongside Pakistan and India in Group A
#
#
# The match scheduled to take place in May 2025 will be Zimbabwe's first tour of England since 2003
#
#
# Asif Khan, named in the 16-man squad vs NZ, is set to make his T20I debut
#
#
# All the updates and match reports from the 2023 season of The Hundred (Men)
#
#
# All the action summed up from the second week of Minor Cricket League in the USA
#
#
# The first season will be held from the 18th to the 27th of August 2023
#
#
# Elsewhere, Brad Wheal's five-fer took Hampshire to victory at Old Trafford
#
#
# News bytes that you may have otherwise missed
#
#
# In a freewheeling chat, the 23-year-old Mumbai and Delhi Capitals batter opens up about his state of mind, his India aspirations and his upcoming County stint
#
#
# In a typically straight-talking interview with Cricbuzz, Jason Holder explains why nobody outside of the Big Three could take England's positive approach to Test cricket, and why the longest format is in its autumn years
#
#
# Australia's famous victory at The Oval was bookended by two outstanding performances from Head and Boland, both fascinating subplots in the success story of Australia under Pat Cummins
#
#
# Boundary hitting is the order of the day in the IPL especially after the introduction of the Impact Player rule and RCB will have to make rapid strides in this department to ensure they don't get left behind
#
#
# Free agency in women's cricket is far less common than in the men's game, but change is coming - particularly with a women's IPL looming into view

# %% [markdown]
# # Amazon Review

# %%
try:
        
    page=requests.get('https://www.amazon.in/Apple-iPhone-11-Pro-256GB/product-reviews/B07XVMJF2D/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews')                             # this might throw an exception if something goes wrong.
    
except Exception as e:                                   
    error_type, error_obj, error_info = sys.exc_info()     
    print ('ERROR FOR LINK:',url)                          
    print (error_type, 'Line:', error_info.tb_lineno)      
                                                 
time.sleep(2)   
soup=BeautifulSoup(page.text,'html.parser')
links=soup.find_all('div',attrs={'class':'a-size-base'})

# %%
for i in links:
    print(i.text)
    print("\n")
# Out:
#
#
#             1,356 total ratings, 347 with reviews
#
#
#
#
#
#
#
#
# There was a problem filtering reviews right now. Please try again later.
#
#
#
#
#
#
#
#
# From India
# Bhagwant Patil4.0 out of 5 stars
# Great iPhone but overpriced.
# Reviewed in India on 2 April 2021Verified Purchase
# I'm writing this review after 1 month of use.Look & feel- premium & satisfyingDisplay- It has OLED display but not much different than previous LCD display of iPhone XR. BOTH ARE STUNNING & elegant. In fact I liked LCD display more.Battery life- Excellent. With heavy use of 2+ hrs of Instagram scrolling 1+ hr of YouTube streaming 2+ hrs of listening to music, battery lasts for a whole day. With moderate use for only calling, texting & some surfing it lasts for 1 & 1/2 day.Camera- amazing shots in daylight. Night mode is great addition. Portrait mode is great in daytime but it doesn't have night mode. Photos loose details after zooming in. Upto 2x zoom is good, after that it's useless.Ultrawide feature is good but didn't used it much. Front camera is okay, could have been better.Performance- Ultrafast & smooth. It had heated a lot when moving data from older phone. Heats when used during charging. Fast charger does its job well.Conclusion- This is a great iPhone but is not a value for money. Overpriced! We can say this about every iPhone. If you are spending this much amount of money you should go for iPhone 12 128GB for about same price but with only 2 snappers which are more than enough. Third snapper in 11 pro doesn't make a difference.If you are waiting for iPhone 13 to be launched & thinking of buying 12 after price drop, then consider iPhone 11 for now - 2 snappers, LCD display(not much different), bigger than pro, value for money.Thanks for reading.
#
# 7 people found this helpful
#
#
#               Helpful
#
#
# Report
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.Nomadic Nordic5.0 out of 5 stars
# Great camera faster face id
# Reviewed in India on 9 October 2019Verified Purchase
# Short: Go for it if you can afford.TL;DR;I've been having Apple ecosystem (MBP, Watch, AirPod, iPad and iPhone) for many years.  However, this is my first release day purchase of an Apple device.  Improved camera module in iPhone 11 pro helped me to arrive at this decision and I believe that this is the single most important feature in iPhone 11 pro.  Mainly -- Introduction of new wide angle lens.- Better color reproduction- Night mode (Some online reviews suggested that this can not be changed and is set by Camera app automatically.  This is not true.  You can disable if needed from the selection controls)- 16:9 format (you can set this to default from Settings->Camera->Preserve Settings->Camera Mode).  This is the default in my case- Portrait mode with light settings.  I found that we can take studio quality pictures using this)Here are some images I took at various settings.  You can see the richness of color in each of these photographs.  The first one was in the morning against rising sun.  Look at the accurate exposure on the lawn even with the presence of direct sunlight.  The last one is part of Blue city Jodhpur with Mehrangarh fort in the backdrop.  Though the blue is a bit saturated, it gives a dramatic look for the photos.In addition to Camera, the overall experience is very fluid and effortless (I'm leaving out the iOS13 features as the same is available on older models as well).There are a few drawbacks though. The phone is bit bulkier than previous models.  The advantage is the increased battery life.  I've been able to use the phone for upto 30 hours with over 4 hours of screen time (mainly reading and videos) and close to 1 hour of call.  That's a great improvement compared to previous versions.The second drawback is the price.  But that's the price you pay for quality.  One should be able to use this phone for 4 years at least with OS upgrades and Security updates coming in continuously (Something which I don't see on Android).
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Nomadic Nordic
#
# 5.0 out of 5 stars
#
#                 Great camera faster face id
#
#
#
#
#
#
#
#                             Reviewed in India on 9 October 2019
#
#
#
#
#
#
#             Short: Go for it if you can afford.TL;DR;I've been having Apple ecosystem (MBP, Watch, AirPod, iPad and iPhone) for many years.  However, this is my first release day purchase of an Apple device.  Improved camera module in iPhone 11 pro helped me to arrive at this decision and I believe that this is the single most important feature in iPhone 11 pro.  Mainly -- Introduction of new wide angle lens.- Better color reproduction- Night mode (Some online reviews suggested that this can not be changed and is set by Camera app automatically.  This is not true.  You can disable if needed from the selection controls)- 16:9 format (you can set this to default from Settings->Camera->Preserve Settings->Camera Mode).  This is the default in my case- Portrait mode with light settings.  I found that we can take studio quality pictures using this)Here are some images I took at various settings.  You can see the richness of color in each of these photographs.  The first one was in the morning against rising sun.  Look at the accurate exposure on the lawn even with the presence of direct sunlight.  The last one is part of Blue city Jodhpur with Mehrangarh fort in the backdrop.  Though the blue is a bit saturated, it gives a dramatic look for the photos.In addition to Camera, the overall experience is very fluid and effortless (I'm leaving out the iOS13 features as the same is available on older models as well).There are a few drawbacks though. The phone is bit bulkier than previous models.  The advantage is the increased battery life.  I've been able to use the phone for upto 30 hours with over 4 hours of screen time (mainly reading and videos) and close to 1 hour of call.  That's a great improvement compared to previous versions.The second drawback is the price.  But that's the price you pay for quality.  One should be able to use this phone for 4 years at least with OS upgrades and Security updates coming in continuously (Something which I don't see on Android).
#
#
#
#                 Images in this review
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 10 people found this helpful
#
#
#               Helpful
#
#
# Report
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.Deepak5.0 out of 5 stars
# Precise in every dimension.
# Reviewed in India on 7 June 2021Verified Purchase
# 1. Box cartonComes with the plastic outer cover as like as Airpod pro. Peel like feather. Black box with the shiny green apple logo makes so minimalistic. Not even a single dent on corner of the box. Really handled well the courier partner.2. Myteriously inside.Contains  IPHONE 11 PRO, 25W CHARGER, LIGHTNING TO USB TYPE-C CABLE, HEADPHONE WITH LIGHTNING CONNECTOR, TWO APPLE STICKERS.3. iPhone 11 proBoth sides of the phone comes with the Ceramic coated toughened glass, rear with the matte finish(Main reason for my purchase).Bezel comes with the same tint as the product color really the craftmanship work.4. Software.Phone comes with pre-installed Operating system version. 13.0> with Garageband, Apple shop, Video apps and so many. My impressed apps like Notes, Reminder, Calls, Messages. Really helps my day-to-day works.Phone secured completely with your face-id (Not KEEPING IMAGE OF YOUR FACE) it scans your face in all the possible directions even it could recognize you stand aside of your phone. It works well even in a pitch black room.5. Battery.For my usage it lasts above 1 day. Using just Whatsapp, Notes, Reminders, Messages, Calls.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Deepak
#
# 5.0 out of 5 stars
#
#                 Precise in every dimension.
#
#
#
#
#
#
#
#                             Reviewed in India on 7 June 2021
#
#
#
#
#
#
#             1. Box cartonComes with the plastic outer cover as like as Airpod pro. Peel like feather. Black box with the shiny green apple logo makes so minimalistic. Not even a single dent on corner of the box. Really handled well the courier partner.2. Myteriously inside.Contains  IPHONE 11 PRO, 25W CHARGER, LIGHTNING TO USB TYPE-C CABLE, HEADPHONE WITH LIGHTNING CONNECTOR, TWO APPLE STICKERS.3. iPhone 11 proBoth sides of the phone comes with the Ceramic coated toughened glass, rear with the matte finish(Main reason for my purchase).Bezel comes with the same tint as the product color really the craftmanship work.4. Software.Phone comes with pre-installed Operating system version. 13.0> with Garageband, Apple shop, Video apps and so many. My impressed apps like Notes, Reminder, Calls, Messages. Really helps my day-to-day works.Phone secured completely with your face-id (Not KEEPING IMAGE OF YOUR FACE) it scans your face in all the possible directions even it could recognize you stand aside of your phone. It works well even in a pitch black room.5. Battery.For my usage it lasts above 1 day. Using just Whatsapp, Notes, Reminders, Messages, Calls.
#
#
#
#                 Images in this review
#
#
#
#
#
#
#
#
#
#
#
#
# 2 people found this helpful
#
#
#               Helpful
#
#
# Report
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.Farhad Tarapore4.0 out of 5 stars
# Superb little package (11 Pro)
# Reviewed in India on 13 March 2020Verified Purchase
# What I love:1. Amazing battery life - lasts me 1.5 days from full charge2. Great speaker quality3. Superb camera - night mode comes on automatically with the option to control shutter speed4. Form factor - love the small form factor5. Superb display6. Fast charging - so used to this coming from my OnePlus 6T7. Face ID works flawlessly - the fingerprint scanner in my OP6T didn't work most of the time.What I don't like:1. No USB-C - this is a major pain since the supplied charger and earphones only need to be lightning port compatible. Can't use any other charger or earphone. Luckily I have my Sony headphones which I use with Bluetooth2. Flimsy quality of the charger wire - feels too fragile - should have been metal sheathed and strong.3. Flimsy quality of the earphone wire4. Price5. Lack of good usability of apps - e.g. no way to mark Messages as 'read' from the notifications center. You need to clear the notifications, then go to Messaging app and open each and every message. Considering that most messages are OTPs, etc. this functionality should be a no-brainer.Overall, I love the phone.
#
# One person found this helpful
#
#
#               Helpful
#
#
# Report
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.Aradhya.inc3.0 out of 5 stars
# Upto the Mark but not too much change & Battery Blunder
# Reviewed in India on 4 October 2019Verified Purchase
# I am always being fan of iOS & Apple Products.Reason:-QualityPerformanceTransparent Customer SupportDesignBuild QualityUpdatesSound QualityPromises too.Going to write review post a week usage.Pros.Display QualityPerformanceSpeedFast chargingCameraEven Selfie camera Quality enhancedTriple camera also good as described.New Color Midnight Green added as a charm.E-SimIP68 better than others.Battery Usage too better then iPhone XS.Durability too.Cons.No 3D Touch.Old Headphones no changesIn india its too much expensiveHeating issueWhile charging please don’t use it bcz thereafter you can fry an egg on it 😂.Low Screen Refresh Rate.Just 10-20% better than iPhone XS.Camera fails in lighting, ma be apple sort-out this in next update.I am giving :-Screen 4/5Design 5/5Performance 4/5 (Heating)Sound 5/5Price 3/5 (too much expensive)Customer Support 5/5Now battery life falls to 84% in Just 400 Charges.Amazon Delivery 3/5 (i am not satisfied bcz they not delivered the product as per promise.Soon i’ll publish the pics shoots on iPhone 11 Pro.Thanks for Reading.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Aradhya.inc
#
# 3.0 out of 5 stars
#
#                 Upto the Mark but not too much change & Battery Blunder
#
#
#
#
#
#
#
#                             Reviewed in India on 4 October 2019
#
#
#
#
#
#
#             I am always being fan of iOS & Apple Products.Reason:-QualityPerformanceTransparent Customer SupportDesignBuild QualityUpdatesSound QualityPromises too.Going to write review post a week usage.Pros.Display QualityPerformanceSpeedFast chargingCameraEven Selfie camera Quality enhancedTriple camera also good as described.New Color Midnight Green added as a charm.E-SimIP68 better than others.Battery Usage too better then iPhone XS.Durability too.Cons.No 3D Touch.Old Headphones no changesIn india its too much expensiveHeating issueWhile charging please don’t use it bcz thereafter you can fry an egg on it 😂.Low Screen Refresh Rate.Just 10-20% better than iPhone XS.Camera fails in lighting, ma be apple sort-out this in next update.I am giving :-Screen 4/5Design 5/5Performance 4/5 (Heating)Sound 5/5Price 3/5 (too much expensive)Customer Support 5/5Now battery life falls to 84% in Just 400 Charges.Amazon Delivery 3/5 (i am not satisfied bcz they not delivered the product as per promise.Soon i’ll publish the pics shoots on iPhone 11 Pro.Thanks for Reading.
#
#
#
#                 Images in this review
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 250 people found this helpful
#
#
#               Helpful
#
#
# Report
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.Ashwin4.0 out of 5 stars
# It will serve you for a year
# Reviewed in India on 30 September 2020Verified Purchase
# Bought this online on 21st October 2019.Sold by Appario and fulfilled by Amazon. The product dispatch and delivery was prompt. Full marks there.A year later, I have noticed that the battery performance is unimpressive on two frontsa) Takes longer to charge than what it shouldb) The phone lasts fewer hours (irrespective of whether in use or idle).The phone-build is commendable and has sustained a few falls.Clearly the chip design is impressive too. I tested this by using my phone as a hotspot, and performed a speed test. I then moved the SIM card to a router and then performed a speed test. Results were contrasting and clearly in favor of the iphone.However, these arent reasons good enough to shell out close to 1 lac INR for a phone, if the expected service duration without issues is just about a year.
#
# One person found this helpful
#
#
#               Helpful
#
#
# Report
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.Gurjeev Shelly5.0 out of 5 stars
# An aesthetically beautiful phone with beast of a processor.
# Reviewed in India on 16 February 2021Verified Purchase
# The best looking phone. I have been an android user for over 9 years and this is my first purchase of iOS. It took me some time to adjust to the know how of iOS but I can happily say that the switch was worth. This phone is miles ahead of even the flagships introduced in late 2020 or early 2021. The camera is a big improvement on this. My previous phone was pixel 2 XL and this seems to have a improved camera over that.Overall, I am very happy with the purchase and stick to this for the next 4 years at least as 5G in India is going to be a distant dream when it Comes to being implemented in all cities.
#
# 3 people found this helpful
#
#
#               Helpful
#
#
# Report
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.Ajit Kumar Samal5.0 out of 5 stars
# My Ear pod is not working properly
# Reviewed in India on 28 January 2022Verified Purchase
# I want to say that on this mobile I got an ear pod and is one side is not working and there is a slight cut near the ear and I have took it to the Apple care but the Apple care person said that we can’t change it nor we can’t do anything if there is any warranty
#
#
#
#
#               Helpful
#
#
# Report
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.Hidayt Rahman4.0 out of 5 stars
# DSLR in your pocket
# Reviewed in India on 16 May 2020Verified Purchase
# I am writing a review after using this for more than 12 months. I am a traveler and passionate photographer. On the few trips, I have used this phone as a DSLR, Photo quality is amazing and the portrait results are outstanding, I can compare it with the DSLR camera.Advantages:The portrait camera is amazingProfessional videography like cinematic shotsBattery LifePerformanceSounds QualityDisadvantagesThe front face camera is poorLow light photography is not up to the markCostlyYou can't set 3rd party camera to video call for apps like (WhatsApp, Instagram, Zoom, Hangouts)Rest use and decideOnly buy if you love photography and videography :)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Hidayt Rahman
#
# 4.0 out of 5 stars
#
#                 DSLR in your pocket
#
#
#
#
#
#
#
#                             Reviewed in India on 16 May 2020
#
#
#
#
#
#
#             I am writing a review after using this for more than 12 months. I am a traveler and passionate photographer. On the few trips, I have used this phone as a DSLR, Photo quality is amazing and the portrait results are outstanding, I can compare it with the DSLR camera.Advantages:The portrait camera is amazingProfessional videography like cinematic shotsBattery LifePerformanceSounds QualityDisadvantagesThe front face camera is poorLow light photography is not up to the markCostlyYou can't set 3rd party camera to video call for apps like (WhatsApp, Instagram, Zoom, Hangouts)Rest use and decideOnly buy if you love photography and videography :)
#
#
#
#                 Images in this review
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 6 people found this helpful
#
#
#               Helpful
#
#
# Report
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.Amazon Customer5.0 out of 5 stars
# SMOOTH, GOOD BATTERY LIFE, best camera
# Reviewed in India on 14 June 2021Verified Purchase
# Iam a android user from past 8 years. But after switching to iOS it's a night and day difference the transition and everything is so smooth. Believe me if your not a hardcore gamer and you want the smartphone for photography, cinematography, social media and for other utilities iphone 11 pro is best .This can also play games without any lag but don't use it over time your battery will suffer.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Amazon Customer
#
# 5.0 out of 5 stars
#
#                 SMOOTH, GOOD BATTERY LIFE, best camera
#
#
#
#
#
#
#
#                             Reviewed in India on 14 June 2021
#
#
#
#
#
#
#             Iam a android user from past 8 years. But after switching to iOS it's a night and day difference the transition and everything is so smooth. Believe me if your not a hardcore gamer and you want the smartphone for photography, cinematography, social media and for other utilities iphone 11 pro is best .This can also play games without any lag but don't use it over time your battery will suffer.
#
#
#
#                 Images in this review
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 2 people found this helpful
#
#
#               Helpful
#
#
# Report
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.←Previous pageNext page→
#
#
#
#
#
#
#
#
#
#
#
# From India
# Bhagwant Patil4.0 out of 5 stars
# Great iPhone but overpriced.
# Reviewed in India on 2 April 2021Verified Purchase
# I'm writing this review after 1 month of use.Look & feel- premium & satisfyingDisplay- It has OLED display but not much different than previous LCD display of iPhone XR. BOTH ARE STUNNING & elegant. In fact I liked LCD display more.Battery life- Excellent. With heavy use of 2+ hrs of Instagram scrolling 1+ hr of YouTube streaming 2+ hrs of listening to music, battery lasts for a whole day. With moderate use for only calling, texting & some surfing it lasts for 1 & 1/2 day.Camera- amazing shots in daylight. Night mode is great addition. Portrait mode is great in daytime but it doesn't have night mode. Photos loose details after zooming in. Upto 2x zoom is good, after that it's useless.Ultrawide feature is good but didn't used it much. Front camera is okay, could have been better.Performance- Ultrafast & smooth. It had heated a lot when moving data from older phone. Heats when used during charging. Fast charger does its job well.Conclusion- This is a great iPhone but is not a value for money. Overpriced! We can say this about every iPhone. If you are spending this much amount of money you should go for iPhone 12 128GB for about same price but with only 2 snappers which are more than enough. Third snapper in 11 pro doesn't make a difference.If you are waiting for iPhone 13 to be launched & thinking of buying 12 after price drop, then consider iPhone 11 for now - 2 snappers, LCD display(not much different), bigger than pro, value for money.Thanks for reading.
#
# 7 people found this helpful
#
#
#               Helpful
#
#
# Report
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.Nomadic Nordic5.0 out of 5 stars
# Great camera faster face id
# Reviewed in India on 9 October 2019Verified Purchase
# Short: Go for it if you can afford.TL;DR;I've been having Apple ecosystem (MBP, Watch, AirPod, iPad and iPhone) for many years.  However, this is my first release day purchase of an Apple device.  Improved camera module in iPhone 11 pro helped me to arrive at this decision and I believe that this is the single most important feature in iPhone 11 pro.  Mainly -- Introduction of new wide angle lens.- Better color reproduction- Night mode (Some online reviews suggested that this can not be changed and is set by Camera app automatically.  This is not true.  You can disable if needed from the selection controls)- 16:9 format (you can set this to default from Settings->Camera->Preserve Settings->Camera Mode).  This is the default in my case- Portrait mode with light settings.  I found that we can take studio quality pictures using this)Here are some images I took at various settings.  You can see the richness of color in each of these photographs.  The first one was in the morning against rising sun.  Look at the accurate exposure on the lawn even with the presence of direct sunlight.  The last one is part of Blue city Jodhpur with Mehrangarh fort in the backdrop.  Though the blue is a bit saturated, it gives a dramatic look for the photos.In addition to Camera, the overall experience is very fluid and effortless (I'm leaving out the iOS13 features as the same is available on older models as well).There are a few drawbacks though. The phone is bit bulkier than previous models.  The advantage is the increased battery life.  I've been able to use the phone for upto 30 hours with over 4 hours of screen time (mainly reading and videos) and close to 1 hour of call.  That's a great improvement compared to previous versions.The second drawback is the price.  But that's the price you pay for quality.  One should be able to use this phone for 4 years at least with OS upgrades and Security updates coming in continuously (Something which I don't see on Android).
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Nomadic Nordic
#
# 5.0 out of 5 stars
#
#                 Great camera faster face id
#
#
#
#
#
#
#
#                             Reviewed in India on 9 October 2019
#
#
#
#
#
#
#             Short: Go for it if you can afford.TL;DR;I've been having Apple ecosystem (MBP, Watch, AirPod, iPad and iPhone) for many years.  However, this is my first release day purchase of an Apple device.  Improved camera module in iPhone 11 pro helped me to arrive at this decision and I believe that this is the single most important feature in iPhone 11 pro.  Mainly -- Introduction of new wide angle lens.- Better color reproduction- Night mode (Some online reviews suggested that this can not be changed and is set by Camera app automatically.  This is not true.  You can disable if needed from the selection controls)- 16:9 format (you can set this to default from Settings->Camera->Preserve Settings->Camera Mode).  This is the default in my case- Portrait mode with light settings.  I found that we can take studio quality pictures using this)Here are some images I took at various settings.  You can see the richness of color in each of these photographs.  The first one was in the morning against rising sun.  Look at the accurate exposure on the lawn even with the presence of direct sunlight.  The last one is part of Blue city Jodhpur with Mehrangarh fort in the backdrop.  Though the blue is a bit saturated, it gives a dramatic look for the photos.In addition to Camera, the overall experience is very fluid and effortless (I'm leaving out the iOS13 features as the same is available on older models as well).There are a few drawbacks though. The phone is bit bulkier than previous models.  The advantage is the increased battery life.  I've been able to use the phone for upto 30 hours with over 4 hours of screen time (mainly reading and videos) and close to 1 hour of call.  That's a great improvement compared to previous versions.The second drawback is the price.  But that's the price you pay for quality.  One should be able to use this phone for 4 years at least with OS upgrades and Security updates coming in continuously (Something which I don't see on Android).
#
#
#
#                 Images in this review
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 10 people found this helpful
#
#
#               Helpful
#
#
# Report
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.Deepak5.0 out of 5 stars
# Precise in every dimension.
# Reviewed in India on 7 June 2021Verified Purchase
# 1. Box cartonComes with the plastic outer cover as like as Airpod pro. Peel like feather. Black box with the shiny green apple logo makes so minimalistic. Not even a single dent on corner of the box. Really handled well the courier partner.2. Myteriously inside.Contains  IPHONE 11 PRO, 25W CHARGER, LIGHTNING TO USB TYPE-C CABLE, HEADPHONE WITH LIGHTNING CONNECTOR, TWO APPLE STICKERS.3. iPhone 11 proBoth sides of the phone comes with the Ceramic coated toughened glass, rear with the matte finish(Main reason for my purchase).Bezel comes with the same tint as the product color really the craftmanship work.4. Software.Phone comes with pre-installed Operating system version. 13.0> with Garageband, Apple shop, Video apps and so many. My impressed apps like Notes, Reminder, Calls, Messages. Really helps my day-to-day works.Phone secured completely with your face-id (Not KEEPING IMAGE OF YOUR FACE) it scans your face in all the possible directions even it could recognize you stand aside of your phone. It works well even in a pitch black room.5. Battery.For my usage it lasts above 1 day. Using just Whatsapp, Notes, Reminders, Messages, Calls.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Deepak
#
# 5.0 out of 5 stars
#
#                 Precise in every dimension.
#
#
#
#
#
#
#
#                             Reviewed in India on 7 June 2021
#
#
#
#
#
#
#             1. Box cartonComes with the plastic outer cover as like as Airpod pro. Peel like feather. Black box with the shiny green apple logo makes so minimalistic. Not even a single dent on corner of the box. Really handled well the courier partner.2. Myteriously inside.Contains  IPHONE 11 PRO, 25W CHARGER, LIGHTNING TO USB TYPE-C CABLE, HEADPHONE WITH LIGHTNING CONNECTOR, TWO APPLE STICKERS.3. iPhone 11 proBoth sides of the phone comes with the Ceramic coated toughened glass, rear with the matte finish(Main reason for my purchase).Bezel comes with the same tint as the product color really the craftmanship work.4. Software.Phone comes with pre-installed Operating system version. 13.0> with Garageband, Apple shop, Video apps and so many. My impressed apps like Notes, Reminder, Calls, Messages. Really helps my day-to-day works.Phone secured completely with your face-id (Not KEEPING IMAGE OF YOUR FACE) it scans your face in all the possible directions even it could recognize you stand aside of your phone. It works well even in a pitch black room.5. Battery.For my usage it lasts above 1 day. Using just Whatsapp, Notes, Reminders, Messages, Calls.
#
#
#
#                 Images in this review
#
#
#
#
#
#
#
#
#
#
#
#
# 2 people found this helpful
#
#
#               Helpful
#
#
# Report
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.Farhad Tarapore4.0 out of 5 stars
# Superb little package (11 Pro)
# Reviewed in India on 13 March 2020Verified Purchase
# What I love:1. Amazing battery life - lasts me 1.5 days from full charge2. Great speaker quality3. Superb camera - night mode comes on automatically with the option to control shutter speed4. Form factor - love the small form factor5. Superb display6. Fast charging - so used to this coming from my OnePlus 6T7. Face ID works flawlessly - the fingerprint scanner in my OP6T didn't work most of the time.What I don't like:1. No USB-C - this is a major pain since the supplied charger and earphones only need to be lightning port compatible. Can't use any other charger or earphone. Luckily I have my Sony headphones which I use with Bluetooth2. Flimsy quality of the charger wire - feels too fragile - should have been metal sheathed and strong.3. Flimsy quality of the earphone wire4. Price5. Lack of good usability of apps - e.g. no way to mark Messages as 'read' from the notifications center. You need to clear the notifications, then go to Messaging app and open each and every message. Considering that most messages are OTPs, etc. this functionality should be a no-brainer.Overall, I love the phone.
#
# One person found this helpful
#
#
#               Helpful
#
#
# Report
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.Aradhya.inc3.0 out of 5 stars
# Upto the Mark but not too much change & Battery Blunder
# Reviewed in India on 4 October 2019Verified Purchase
# I am always being fan of iOS & Apple Products.Reason:-QualityPerformanceTransparent Customer SupportDesignBuild QualityUpdatesSound QualityPromises too.Going to write review post a week usage.Pros.Display QualityPerformanceSpeedFast chargingCameraEven Selfie camera Quality enhancedTriple camera also good as described.New Color Midnight Green added as a charm.E-SimIP68 better than others.Battery Usage too better then iPhone XS.Durability too.Cons.No 3D Touch.Old Headphones no changesIn india its too much expensiveHeating issueWhile charging please don’t use it bcz thereafter you can fry an egg on it 😂.Low Screen Refresh Rate.Just 10-20% better than iPhone XS.Camera fails in lighting, ma be apple sort-out this in next update.I am giving :-Screen 4/5Design 5/5Performance 4/5 (Heating)Sound 5/5Price 3/5 (too much expensive)Customer Support 5/5Now battery life falls to 84% in Just 400 Charges.Amazon Delivery 3/5 (i am not satisfied bcz they not delivered the product as per promise.Soon i’ll publish the pics shoots on iPhone 11 Pro.Thanks for Reading.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Aradhya.inc
#
# 3.0 out of 5 stars
#
#                 Upto the Mark but not too much change & Battery Blunder
#
#
#
#
#
#
#
#                             Reviewed in India on 4 October 2019
#
#
#
#
#
#
#             I am always being fan of iOS & Apple Products.Reason:-QualityPerformanceTransparent Customer SupportDesignBuild QualityUpdatesSound QualityPromises too.Going to write review post a week usage.Pros.Display QualityPerformanceSpeedFast chargingCameraEven Selfie camera Quality enhancedTriple camera also good as described.New Color Midnight Green added as a charm.E-SimIP68 better than others.Battery Usage too better then iPhone XS.Durability too.Cons.No 3D Touch.Old Headphones no changesIn india its too much expensiveHeating issueWhile charging please don’t use it bcz thereafter you can fry an egg on it 😂.Low Screen Refresh Rate.Just 10-20% better than iPhone XS.Camera fails in lighting, ma be apple sort-out this in next update.I am giving :-Screen 4/5Design 5/5Performance 4/5 (Heating)Sound 5/5Price 3/5 (too much expensive)Customer Support 5/5Now battery life falls to 84% in Just 400 Charges.Amazon Delivery 3/5 (i am not satisfied bcz they not delivered the product as per promise.Soon i’ll publish the pics shoots on iPhone 11 Pro.Thanks for Reading.
#
#
#
#                 Images in this review
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 250 people found this helpful
#
#
#               Helpful
#
#
# Report
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.Ashwin4.0 out of 5 stars
# It will serve you for a year
# Reviewed in India on 30 September 2020Verified Purchase
# Bought this online on 21st October 2019.Sold by Appario and fulfilled by Amazon. The product dispatch and delivery was prompt. Full marks there.A year later, I have noticed that the battery performance is unimpressive on two frontsa) Takes longer to charge than what it shouldb) The phone lasts fewer hours (irrespective of whether in use or idle).The phone-build is commendable and has sustained a few falls.Clearly the chip design is impressive too. I tested this by using my phone as a hotspot, and performed a speed test. I then moved the SIM card to a router and then performed a speed test. Results were contrasting and clearly in favor of the iphone.However, these arent reasons good enough to shell out close to 1 lac INR for a phone, if the expected service duration without issues is just about a year.
#
# One person found this helpful
#
#
#               Helpful
#
#
# Report
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.Gurjeev Shelly5.0 out of 5 stars
# An aesthetically beautiful phone with beast of a processor.
# Reviewed in India on 16 February 2021Verified Purchase
# The best looking phone. I have been an android user for over 9 years and this is my first purchase of iOS. It took me some time to adjust to the know how of iOS but I can happily say that the switch was worth. This phone is miles ahead of even the flagships introduced in late 2020 or early 2021. The camera is a big improvement on this. My previous phone was pixel 2 XL and this seems to have a improved camera over that.Overall, I am very happy with the purchase and stick to this for the next 4 years at least as 5G in India is going to be a distant dream when it Comes to being implemented in all cities.
#
# 3 people found this helpful
#
#
#               Helpful
#
#
# Report
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.Ajit Kumar Samal5.0 out of 5 stars
# My Ear pod is not working properly
# Reviewed in India on 28 January 2022Verified Purchase
# I want to say that on this mobile I got an ear pod and is one side is not working and there is a slight cut near the ear and I have took it to the Apple care but the Apple care person said that we can’t change it nor we can’t do anything if there is any warranty
#
#
#
#
#               Helpful
#
#
# Report
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.Hidayt Rahman4.0 out of 5 stars
# DSLR in your pocket
# Reviewed in India on 16 May 2020Verified Purchase
# I am writing a review after using this for more than 12 months. I am a traveler and passionate photographer. On the few trips, I have used this phone as a DSLR, Photo quality is amazing and the portrait results are outstanding, I can compare it with the DSLR camera.Advantages:The portrait camera is amazingProfessional videography like cinematic shotsBattery LifePerformanceSounds QualityDisadvantagesThe front face camera is poorLow light photography is not up to the markCostlyYou can't set 3rd party camera to video call for apps like (WhatsApp, Instagram, Zoom, Hangouts)Rest use and decideOnly buy if you love photography and videography :)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Hidayt Rahman
#
# 4.0 out of 5 stars
#
#                 DSLR in your pocket
#
#
#
#
#
#
#
#                             Reviewed in India on 16 May 2020
#
#
#
#
#
#
#             I am writing a review after using this for more than 12 months. I am a traveler and passionate photographer. On the few trips, I have used this phone as a DSLR, Photo quality is amazing and the portrait results are outstanding, I can compare it with the DSLR camera.Advantages:The portrait camera is amazingProfessional videography like cinematic shotsBattery LifePerformanceSounds QualityDisadvantagesThe front face camera is poorLow light photography is not up to the markCostlyYou can't set 3rd party camera to video call for apps like (WhatsApp, Instagram, Zoom, Hangouts)Rest use and decideOnly buy if you love photography and videography :)
#
#
#
#                 Images in this review
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 6 people found this helpful
#
#
#               Helpful
#
#
# Report
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.Amazon Customer5.0 out of 5 stars
# SMOOTH, GOOD BATTERY LIFE, best camera
# Reviewed in India on 14 June 2021Verified Purchase
# Iam a android user from past 8 years. But after switching to iOS it's a night and day difference the transition and everything is so smooth. Believe me if your not a hardcore gamer and you want the smartphone for photography, cinematography, social media and for other utilities iphone 11 pro is best .This can also play games without any lag but don't use it over time your battery will suffer.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Amazon Customer
#
# 5.0 out of 5 stars
#
#                 SMOOTH, GOOD BATTERY LIFE, best camera
#
#
#
#
#
#
#
#                             Reviewed in India on 14 June 2021
#
#
#
#
#
#
#             Iam a android user from past 8 years. But after switching to iOS it's a night and day difference the transition and everything is so smooth. Believe me if your not a hardcore gamer and you want the smartphone for photography, cinematography, social media and for other utilities iphone 11 pro is best .This can also play games without any lag but don't use it over time your battery will suffer.
#
#
#
#                 Images in this review
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 2 people found this helpful
#
#
#               Helpful
#
#
# Report
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.←Previous pageNext page→

# %%
import requests

# %%
pip install BeautifulSoup4
# Out:
# Requirement already satisfied: BeautifulSoup4 in c:\users\shakhawat chowdhury\anaconda3\lib\site-packages (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\shakhawat chowdhury\anaconda3\lib\site-packages (from BeautifulSoup4) (2.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
file = requests.get("https://weather.com/en-IN/weather/tenday/l/INKA0344:1:IN")
from bs4 import BeautifulSoup
soup = BeautifulSoup(file.content, "html.parser")
list =[]
all = soup.find("div", {"class":"locations-title ten-day-page-title"}).find("h1").text

# find all table with class-"twc-table"
content = soup.find_all('details', {'id': re.compile(r'^detailIndex')})
for items in content:
    for i in range(len(items.find_all("tr"))-1):
        dict = {}
        try:
            dict["day"]= items.find_all("span", {"class":"date-time"})[i].text
            dict["date"]= items.find_all("span", {"class":"day-detail"})[i].text
            dict["desc"]= items.find_all("td", {"class":"description"})[i].text
            dict["temp"]= items.find_all("td", {"class":"temp"})[i].text
            dict["precip"]= items.find_all("td", {"class":"precip"})[i].text
            dict["wind"]= items.find_all("td", {"class":"wind"})[i].text
            dict["humidity"]= items.find_all("td", {"class":"humidity"})[i].text
        except:
            dict["day"]="None"
            dict["date"]="None"
            dict["desc"]="None"
            dict["temp"]="None"
            dict["precip"]="None"
            dict["wind"]="None"
            dict["humidity"]="None"

        list.append(dict)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 3
#       1 # create empty list
#       2 list =[]
# ----> 3 all = soup.find("div", {"class":"locations-title ten-day-page-title"}).find("h1").text
#       5 # find all table with class-"twc-table"
#       6 content = soup.find_all("table", {"class":"twc-table"})
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
import pandas as pd
convert = pd.DataFrame(list)
convert.to_csv("output.csv")
# read csv file using pandas
a = pd.read_csv("output.csv")
print(a)

# %%
from selenium import webdriver
from BeautifulSoup import BeautifulSoup
import pandas as pd

# %%
driver = webdriver.Chrome("/usr/lib/chromium-browser/chromedriver")

# %%
products=[] #List to store name of the product
prices=[] #List to store price of the product
ratings=[] #List to store rating of the product
driver.get("<a href="https://www.flipkart.com/laptops/">https://www.flipkart.com/laptops/</a>~buyback-guarantee-on-laptops-/pr?sid=6bo%2Cb5g&amp;amp;amp;amp;amp;amp;amp;amp;amp;uniq")

# %%
content = driver.page_source
soup = BeautifulSoup(content)
for a in soup.findAll('a',href=True, attrs={'class':'_31qSD5'}):
name=a.find('div', attrs={'class':'_3wU53n'})
price=a.find('div', attrs={'class':'_1vC4OE _2rQ-NK'})
rating=a.find('div', attrs={'class':'hGSR34 _2beYZw'})
products.append(name.text)
prices.append(price.text)
ratings.append(rating.text)

# %%
python web-s.py

# %%
df = pd.DataFrame({'Product Name':products,'Price':prices,'Rating':ratings}) 
df.to_csv('products.csv', index=False, encoding='utf-8')

# %%
import requests 
from bs4 import BeautifulSoup
import re
